# %% [markdown]
# <a href="https://colab.research.google.com/github/Tikuh5/2024_Geoinformatique_I/blob/main/ogr2ogr_populace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install gdal-bin
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   python3-gdal python3-numpy
# Suggested packages:
#   libgdal-grass python-numpy-doc python3-pytest
# The following NEW packages will be installed:
#   gdal-bin python3-gdal python3-numpy
# 0 upgraded, 3 newly installed, 0 to remove and 49 not upgraded.
# Need to get 5,055 kB of archives.
# After this operation, 25.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-numpy amd64 1:1.21.5-1ubuntu22.04.1 [3,467 kB]
# Get:2 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 python3-gdal amd64 3.6.4+dfsg-1~jammy0 [1,027 kB]
# Get:3 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 gdal-bin amd64 3.6.4+dfsg-1~jammy0 [561 kB]
# Fetched 5,055 kB in 3s (1,595 kB/s)
# Selecting previously unselected package python3-numpy.
# ...

# %%
# !ogr2ogr
# Out:
# Usage: ogr2ogr [--help-general] [-skipfailures] [-append | -upsert] [-update]
#                [-select field_list] [-where restricted_where|@filename]
#                [-progress] [-sql <sql statement>|@filename] [-dialect dialect]
#                [-preserve_fid] [-fid FID] [-limit nb_features]
#                [-spat xmin ymin xmax ymax] [-spat_srs srs_def] [-geomfield field]
#                [-a_srs srs_def] [-t_srs srs_def] [-s_srs srs_def] [-ct string]
#                [-f format_name] [-overwrite] [[-dsco NAME=VALUE] ...]
#                dst_datasource_name src_datasource_name
#                [-lco NAME=VALUE] [-nln name]
#                [-nlt type|PROMOTE_TO_MULTI|CONVERT_TO_LINEAR|CONVERT_TO_CURVE]
#                [-dim XY|XYZ|XYM|XYZM|layer_dim] [layer [layer ...]]
#
# Advanced options :
#                [-gt n] [-ds_transaction]
#                [[-oo NAME=VALUE] ...] [[-doo NAME=VALUE] ...]
#                [-clipsrc [xmin ymin xmax ymax]|WKT|datasource|spat_extent]
# ...

# %%
##Données sur la population 2023

from google.colab import files
uploaded = files.upload()
# !apt-get update
# !apt-get install -y gdal-bin python3-gdal
# !ogr2ogr --version
# !ogr2ogr -f "GPKG" /content/ofs_geostat.gpkg /content/STATPOP2023.csv -nln pop_2023 -oo X_POSSIBLE_NAMES=E_KOORD -oo Y_POSSIBLE_NAMES=N_KOORD -a_srs EPSG:2056 -select BBTOT,E_KOORD,N_KOORD -spat 2550096 1177734 2570096 1197734
from google.colab import files
files.download('/content/ofs_geostat.gpkg')

##Données sur les emplois 2022

from google.colab import files
uploaded = files.upload()

# !ogr2ogr -update -nln empl_2022 -oo X_POSSIBLE_NAMES=E_KOORD -oo Y_POSSIBLE_NAMES=N_KOORD -a_srs EPSG:2056 -select "B08EMPT,E_KOORD,N_KOORD" -mapFieldType All=Integer /content/ofs_geostat.gpkg /content/STATPOP_2022.csv -spat 2550096 1177734 2570096 1197734

from google.colab import files
files.download('/content/ofs_geostat.gpkg')
# Out:
#      <input type="file" id="files-c4a485e4-03b5-495e-a571-69b872170ae2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c4a485e4-03b5-495e-a571-69b872170ae2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
##Données sur la population 2023

from google.colab import files
uploaded = files.upload()

# !apt-get update
# !apt-get install -y gdal-bin python3-gdal

# !ogr2ogr --version

# !ogr2ogr -f "GPKG" /content/ofs_geostat.gpkg /content/STATPOP2023.csv -nln pop_2023 -oo X_POSSIBLE_NAMES=E_KOORD -oo Y_POSSIBLE_NAMES=N_KOORD -a_srs EPSG:2056 -select BBTOT,E_KOORD,N_KOORD -spat 2550096 1177734 2570096 1197734

from google.colab import files
files.download('/content/ofs_geostat.gpkg')

##Données sur les emplois 2022

from google.colab import files
uploaded = files.upload()

# !ogr2ogr -update -nln empl_2023 -oo X_POSSIBLE_NAMES=E_KOORD -oo Y_POSSIBLE_NAMES=N_KOORD -a_srs EPSG:2056 -select "B08EMPT,E_KOORD,N_KOORD" -mapFieldType All=Integer /content/ofs_geostat.gpkg /content/STATPOP_2023.csv -spat 2550096 1177734 2570096 1197734

from google.colab import files
files.download('/content/ofs_geostat.gpkg')
# Out:
#      <input type="file" id="files-15d26e7b-13d1-494d-862d-c723353949b0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15d26e7b-13d1-494d-862d-c723353949b0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
